# %% [markdown]
# # 1. Examine the dataset. Are there any missing observations or columns where the data do not seem valid?

# %%
#installing modules 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
training = pd.read_csv('training.csv')
#checking for missing values
print(training[training.isnull()].count().sum())
# Out:
# 0

# %% [markdown]
# # 2. Get basic descriptive statistics for the dataset.

# %%
training.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
training.rename(columns={'Q1':'age','Q2':'gender',
                         'Q3':'marital_status','Q4':'highest education'
                        ,'Q5':'Which_of_the_following_applies_to_you?',
                         'Q6':'land_owner','Q7':'own_a_mobile',
                         'Q8_1':'salaries','Q8_2':'money_from_trading',
                         'Q8_3':'money_from_providing_service',
                         'Q8_4':'piece_work','Q8_5':'rental_income',
                    'Q8_6':'interest_from_savings','Q8_7':'Pension',
                         'Q8_8':'social_welfare_money','Q8_9':'rely_on_someone_else',
                         'Q8_10':"don't_get_money",'Q8_11':'other'}, inplace=True)

# %%
number_to_gender= {
    1:'female',
    2:'male'
}
mobile_mney={
    0:'no',
    1:'yes'
    
}
mmc= {
    0:'no_mobile_money',
    1:'no_mbl_mny_but_one_finacial_service',
    2:'mobile_money_only',
    3:'mobile_money_and_other'
}
ms={
    1:'married',
    2:'divorced',
    3:'widowed',
    4:'single/never_married'
}
svng={
    0:'no',
    1:'yes'
}
lo={
    1:'yes',
    2:'no'
}
training.gender = training.gender.map(number_to_gender)
training.mobile_money_classification = training.mobile_money_classification.map(mmc)
training.marital_status = training.marital_status.map(ms)
training.mobile_money = training.mobile_money.map(mobile_mney)
training.savings = training.savings.map(svng)
training.land_owner = training.land_owner.map(lo)

# %%
training.head()
# Out:
#      ID  age  gender        marital_status  highest education  \
# 0  5086   98    male               widowed                  1
# 1  1258   40  female               married                  3
# 2   331   18    male  single/never_married                  6
# 3  6729   50  female               married                  3
# 4  8671   34  female               married                  1
#
#    Which_of_the_following_applies_to_you? land_owner  own_a_mobile  salaries  \
# 0                                       1         no             2         0
# 1                                       5        yes             1         1
# 2                                       3         no             1         0
# 3                                       1        yes             1         0
# 4                                       1         no             1         0
#
#    money_from_trading  ...  Q17  Q18  Q19  Latitude  Longitude  mobile_money  \
# ...

# %% [markdown]
# # 3.Create appropriate graphs to visually represent the relationship between financial services accessed (non-mobile, mobile, both) and age, gender, marital status, land ownership and type of income.

# %%
#people with mobile money and people without
training.mobile_money.value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("Mobile money", labelpad=14)
plt.ylabel("no. of people ", labelpad=14)
plt.title("people with mobile money and people without", y=1.02)
plt.legend()
plt.show()

# %%
training.mobile_money_classification.value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("Mobile money classification", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
training.savings.value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
#training.Q1.value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("savings", labelpad=14)
plt.ylabel("Count of People", labelpad=14)
plt.title("people with savings", y=1.02)
plt.legend()
plt.show()

# %%
training.mobile_money.value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("Gender", labelpad=14)
plt.ylabel("Count of People", labelpad=14)
plt.title("number of People using mobile money", y=1.02)
plt.legend(labels = ['0 = Male','1 = Female'])
plt.show()

# %% [markdown]
# ## financial services accessed with mobile

# %%
fk = training[training.mobile_money == 'yes']
kf = training[training.mobile_money == 'no']
fk.savings.value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("yes and no", labelpad=14)
plt.ylabel("Count of People", labelpad=14)
plt.title("number of People with savings", y=1.02)
plt.legend(labels = ['Male','Female'])
plt.show()

# %%
#people with mobile_money 
fk.age.value_counts().plot(kind='bar', figsize=(20, 6), rot=7)
plt.show()

# %%
#people with mobile_money gender
fk.gender.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
# plt.show()

# %% [markdown]
# marital_status with mobile money

# %%
fk.marital_status.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
fk.land_owner.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
fk.mobile_money_classification.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %% [markdown]
# ## financial services accessed without mobile

# %%
kf.gender.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
# plt.show()

# %%
kf.marital_status.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
#people without mobile_money age
kf.age.value_counts().plot(kind='bar', figsize=(20, 6), rot=7)
plt.show()

# %%
kf.land_owner.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
kf.mobile_money_classification.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %% [markdown]
# ## both financial services accessed

# %%
both = training[training.mobile_money_classification == 'mobile_money_and_other']
both.age.value_counts().plot(kind='bar', figsize=(20, 6), rot=7)
plt.show()

# %%
#display the gender for both finacial service
both.gender.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
both.marital_status.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
both.land_owner.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
both.mobile_money_classification.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
training.head()
# Out:
#      ID  age  gender        marital_status  highest education  \
# 0  5086   98    male               widowed                  1
# 1  1258   40  female               married                  3
# 2   331   18    male  single/never_married                  6
# 3  6729   50  female               married                  3
# 4  8671   34  female               married                  1
#
#    Which_of_the_following_applies_to_you? land_owner  own_a_mobile  salaries  \
# 0                                       1         no             2         0
# 1                                       5        yes             1         1
# 2                                       3         no             1         0
# 3                                       1        yes             1         0
# 4                                       1         no             1         0
#
#    money_from_trading  ...  Q17  Q18  Q19  Latitude  Longitude  mobile_money  \
# ...

# %% [markdown]
# # 4.Create appropriate graphs to visually represent the relationship between how often mobile services are used and age, gender, marital status, land ownership and type of income.

# %%
mobile_service = training[training.mobile_money_classification == 'mobile_money_only']
mobile_service.head()
# Out:
#       ID  age gender        marital_status  highest education  \
# 2    331   18   male  single/never_married                  6
# 11  2536   29   male               married                  6
# 14  3543   22   male  single/never_married                  6
# 16  7769   21   male  single/never_married                  6
# 30  3158   53   male              divorced                  1
#
#     Which_of_the_following_applies_to_you? land_owner  own_a_mobile  salaries  \
# 2                                        3         no             1         0
# 11                                       1         no             1         0
# 14                                       5         no             1         0
# 16                                       3         no             1         0
# 30                                       1         no             1         0
#
#     money_from_trading  ...  Q17  Q18  Q19   Latitude  Longitude  \
# ...

# %%
mobile_service.age.value_counts().plot(kind='bar', figsize=(20, 6), rot=7)
plt.show()

# %%
mobile_service.gender.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
mobile_service.marital_status.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %%
mobile_service.land_owner.value_counts().plot(kind='bar', figsize=(7, 6), rot=7)
plt.show()

# %% [markdown]
# # 1.Create a map to visually explore geographic distribution of mobile services coverage with respect to type of income.

# %%
import folium
# maap = folium.Map(location=[6.3690 , 34.8888], zoom_start=13) 
# display(maap)
# maap.save('index.html')


# tooltip = 'Click me!'

# folium.Marker([29.811396, -4.460442], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(maap)
# folium.Marker([39.244871, -6.176438], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)

maap = folium.Map(
    location=[-6.3690281, 34.8888206],
    zoom_start=15,
)

tooltip = 'Click me!'

folium.Marker([-7.179645, 31.039095], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(maap)
folium.Marker([-6.176438, 39.244871], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-6.180251, 39.237294], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-8.386770, 39.768192], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-4.887248, 29.639578], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-1.084000, 31.807186], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-11.217201,36.981760], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
display(maap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(training.Latitude.value_counts())
print(training.Longitude.value_counts())
# Out:
# -5.245700     3
# -6.931571     3
# -6.180251     3
# -4.887248     3
# -8.386770     3
#              ..
# -2.107515     1
# -3.282207     1
# -9.409294     1
# -10.203700    1
# -3.681216     1
# Name: Latitude, Length: 7056, dtype: int64
# 39.778715    3
# 33.230579    3
# 39.237294    3
# 29.639578    3
# 39.768192    3
#             ..
# 33.354569    1
# 39.123219    1
# 33.126023    1
# 39.117283    1
# 33.451491    1
# Name: Longitude, Length: 7055, dtype: int64

# %%
training[training.mobile_money == "yes"].sort_values('Latitude')
# Out:
#         ID  age  gender        marital_status  highest education  \
# 2988  8218   17  female  single/never_married                  5
# 3511  8263   38  female               married                  2
# 1706  7102   39  female               married                  3
# 74    7050   25  female               married                  6
# 71    8883   45  female               married                  6
# ...    ...  ...     ...                   ...                ...
# 504   6969   23  female               married                  3
# 4994  2643   38    male               widowed                  3
# 526   5347   35  female               married                  3
# 1217  5331   38  female               married                  3
# 1936  5342   45    male               married                  3
#
#       Which_of_the_following_applies_to_you? land_owner  own_a_mobile  \
# 2988                                       3         no             1
# ...

# %%
# sns.lineplot(x="mobile_money_classification", y="savings", data=training)
sns.lineplot(x="borrowing", y="mobile_money_classification", data=training)
# sns.lineplot(x="mobile_money_classification", y="insurance", data=training)
# plt.legend()

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # Map rendering library
# create empty map object for the COuntry_map using latitude and longitude values
lat = [-6.8234901] ; lon = [39.2695084]
Country_map = folium.Map(location=[lat, lon], zoom_start=11)
# add markers to map
for lat, lng, label in (training['Latitude'], training['Longitude'], 
                          training['*args']):
   label = folium.Popup(label, parse_html=True)
   folium.CircleMarker(
       [lat, lng],
       radius=5,
       popup=label,
       color='blue',
       fill=True,
       fill_color='#3186cc',
       fill_opacity=0.7,
       parse_html=False).add_to(Country_map)  
   
Country_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/folium/utilities.py in validate_location(location)
#      58         try:
# ---> 59             float(coord)
#      60         except (TypeError, ValueError):
#
# TypeError: float() argument must be a string or a number, not 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-c7a787fe7f27> in <module>
#       3 # create empty map object for the COuntry_map using latitude and longitude values
#       4 lat = [-6.8234901] ; lon = [39.2695084]
# ----> 5 Country_map = folium.Map(location=[lat, lon], zoom_start=11)
#       6 # add markers to map
#       7 for lat, lng, label in (training['Latitude'], training['Longitude'],
#
# ...

# %%
import geopy.geocoders

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # Map rendering library
# create empty map object for the COuntry_map using latitude and longitude values
lat = -6.3728253 ; lon = 34.8924826
Country_map = folium.Map(location=[lat, lon], zoom_start=5)
# add markers to map
for lat, lng, label in zip(training['Latitude'], training['Longitude'], 
                           str(training.ID)):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Country_map)  
for lat, lng, label in zip(widowed[widowed.mobile_money == 1].Latitude, 
                           widowed[widowed.mobile_money == 1].Longitude, 
                           str(tanzania_data.ID)):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.4,
        parse_html=False).add_to(Country_map) 
# for lat, lng, label in zip(widowed[widowed.mobile_money == 0].Latitude, 
#                            widowed[widowed.mobile_money == 0].Longitude, 
#                            tanzania_data.ID):
#     label = folium.Popup(label, parse_html=True)
#     folium.CircleMarker(
#         [lat, lng],
#         radius=5,
#         popup=label,
#         color='red',
#         fill=True,
#         fill_color='#3186cc',
#         fill_opacity=0.4,
#         parse_html=False).add_to(Country_map) 
plt.savefig('map_of_tanz_without_mm.png')
Country_map

# %%
df = training[["mobile_money_classification","Q1"]]
sns.lineplot(x="mobile_money_classification", y="Q1", data=training)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ec71e0e30965> in <module>
# ----> 1 df = training[["mobile_money_classification","Q1"]]
#       2 sns.lineplot(x="mobile_money_classification", y="Q1", data=training)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...
